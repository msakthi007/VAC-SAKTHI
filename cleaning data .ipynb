# %% [markdown]
# <a href="https://colab.research.google.com/github/msakthi007/VAC-SAKTHI/blob/main/cleaning%20data%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import Normalizer

# %%
normalization_df=pd.DataFrame({'x':np.random.randint(-100,100,1000),'y':np.random.randint(-80,80,1000),'z':np.random.randint(20,40,1000)})

# %%
normalization_df
# Out:
#       x   y   z
# 0   -34   8  27
# 1    32 -37  21
# 2    38  -3  34
# 3   -27 -40  20
# 4    81  16  23
# ..   ..  ..  ..
# 995  60  33  22
# 996 -25  76  30
# 997 -61 -35  27
# 998 -37  -9  25
# 999   0  15  26
#
# [1000 rows x 3 columns]

# %%
from numpy.random.mtrand import normal
ax=plt.axes(projection='3d')

ax.scatter3D(normalization_df.x,normalization_df.y,
             normalization_df.z)
plt.figure()

# %%
nol=Normalizer()

# %%
normalization_df=nol.fit_transform(normalization_df)

# %%
normalization_df
# Out:
# array([[-0.77014588,  0.1812108 ,  0.61158644],
#        [ 0.60110461, -0.6950272 ,  0.3944749 ],
#        [ 0.74395481, -0.05873327,  0.66564378],
#        ...,
#        [-0.80974244, -0.46460632,  0.35841059],
#        [-0.81225552, -0.19757567,  0.5488213 ],
#        [ 0.        ,  0.49972245,  0.86618559]])

# %%
norm=pd.DataFrame(normalization_df,columns=["x","y","z"])

# %%
ax=plt.axes(projection='3d')

ax.scatter3D(norm.x,norm.y,
          norm.z)
plt.figure()

# %%
data=({'first score':[100,90,np.nan,85],
      'second score':[45,54,76,np.nan],
      'third score':[np.nan,50,65,43,]})

# %%
data
# Out:
# {'first score': [100, 90, nan, 85],
#  'second score': [45, 54, 76, nan],
#  'third score': [nan, 50, 65, 43]}

# %%
sk=pd.DataFrame()

# %%
sk
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
imputer.fit(var)
imputer.transform(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-08c04e1ad111> in <module>
# ----> 1 imputer.fit(var)
#       2 imputer.transform(var)
#
# NameError: name 'var' is not defined
